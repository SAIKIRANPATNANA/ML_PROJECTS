# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('/home/user/Documents/ML_DL_PROJECTS/CropRecommendationClassificationMLProject/dataset/Crop_recommendation.csv')

# %%
df.dtypes
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# label           object
# dtype: object

# %%
len(df.label.unique())
# Out:
# 22

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
y
# Out:
# 0         rice
# 1         rice
# 2         rice
# 3         rice
# 4         rice
#          ...
# 2195    coffee
# 2196    coffee
# 2197    coffee
# 2198    coffee
# 2199    coffee
# Name: label, Length: 2200, dtype: object

# %%
(df1,df2) = train_test_split(df,test_size=0.25,random_state=42)

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.drop_duplicates()
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
df.dropna()
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
df.isna().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.label.unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
li  = ['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
       'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
       'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
       'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee']

# %%
li = sorted(li)
for i in li
# Out:
# ['apple',
#  'banana',
#  'blackgram',
#  'chickpea',
#  'coconut',
#  'coffee',
#  'cotton',
#  'grapes',
#  'jute',
#  'kidneybeans',
#  'lentil',
#  'maize',
#  'mango',
#  'mothbeans',
#  'mungbean',
#  'muskmelon',
#  'orange',
#  'papaya',
#  'pigeonpeas',
#  'pomegranate',
#  'rice',
#  'watermelon']

# %%
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
len(df.label.unique())
# Out:
# 22

# %%
num_df = df.select_dtypes(exclude='object')

# %%
num_df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340
# ...   ...  ..  ..          ...        ...       ...         ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041
#
# [2200 rows x 7 columns]

# %%
cat_df = df.select_dtypes(include='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15, 8))
sns.boxplot(data=num_df)
plt.title('Boxplot of Outliers for Each Numerical Feature')
plt.xticks(rotation=45)
plt.show()

# %%
# Z-Score method
z_scores = ((num_df - num_df.mean()) / num_df.std()).abs()
outliers_z = (z_scores > 3).any(axis=1)
outliers_indices_z = outliers_z[outliers_z].index

# IQR method
Q1 = num_df.quantile(.15)
Q3 = num_df.quantile(.85)
IQR = Q3 - Q1
outliers_iqr = ((num_df< (Q1 - 1.5 * IQR)) | (num_df > (Q3 + 1.5 * IQR))).any(axis=1)
outliers_indices_iqr = outliers_iqr[outliers_iqr].index

# %%
len(outliers_indices_z)
# Out:
# 171

# %%
len(outliers_indices_iqr)
# Out:
# 209

# %%
outliers_indices_iqr
# Out:
# Index([ 507,  518,  529,  546,  557,  563,  582,  594,  599, 1200,
#        ...
#        1590, 1591, 1592, 1593, 1594, 1595, 1596, 1597, 1598, 1599],
#       dtype='int64', length=209)

# %%
c = 0
li = []
for i in outliers_indices_z:
    if(i in outliers_indices_iqr):
        li.append(i)
        c += 1
for i in outliers_indices_iqr:
    if(i in outliers_indices_z):
        li.append(i)
        c += 1

# %%
df1 = df.copy()

# %%
df1 = df1.drop(li)

# %%
df1.shape
# Out:
# (2093, 8)

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.iloc[:,:-1]

# %%
y = df.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
y_train.shape
# Out:
# (1650,)

# %%
from sklearn.preprocessing import StandardScaler 
from sklearn.preprocessing import LabelEncoder
std = StandardScaler()
lenc = LabelEncoder()
y_train = lenc.fit_transform(y_train)
y_test = lenc.transform(y_test)
x_train = std.fit_transform(x_train)
x_test = std.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %%
logicstic_regression = LogisticRegression()
decision_tree = DecisionTreeClassifier()
random_forest = RandomForestClassifier()
support_vector =   SVC()
k_neighbors = KNeighborsClassifier()
gaussian_nb = GaussianNB()
gradienct_boosting = GradientBoostingClassifier()
xgb = XGBClassifier()
lgbm = LGBMClassifier()

# %%
models = {
    'logicstic_regression' : LogisticRegression(),
    'decision_tree' : DecisionTreeClassifier(),
    'random_forest' : RandomForestClassifier(),
    'support_vector' :   SVC(),
    'k_neighbors' : KNeighborsClassifier(),
    'gaussian_nb' : GaussianNB(),
    'gradienct_boosting' : GradientBoostingClassifier(),
    'xgb' : XGBClassifier(),
    'lgbm' : LGBMClassifier(),
}

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc
# import matplotlib.pyplot as plt

# fpr, tpr, _ = roc_curve(y_true, y_scores)
# roc_auc = auc(fpr, tpr)

# plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc))
# plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver Operating Characteristic Curve')
# plt.legend(loc='lower right')
# plt.show()

# %%
def evaluate_model(y_test, y_pred):
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')
    cm = confusion_matrix(y_test, y_pred)
    return accuracy, precision, recall, f1, cm

# %%
list(models.keys())[0]
# Out:
# 'logicstic_regression'

# %%
y_test.shape
# Out:
# (550,)

# %%
model_report = dict()
for i in range(len(models)):
    model = list(models.values())[i]
    model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    accuracy,precision,recall,f1,cm = evaluate_model(y_test,y_pred)
    model_report[list(models.keys())[i]] = accuracy
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003169 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1338
# [LightGBM] [Info] Number of data points in the train set: 1650, number of used features: 7
# [LightGBM] [Info] Start training from score -3.145851
# [LightGBM] [Info] Start training from score -3.064725
# [LightGBM] [Info] Start training from score -3.077797
# [LightGBM] [Info] Start training from score -3.174424
# [LightGBM] [Info] Start training from score -3.118071
# [LightGBM] [Info] Start training from score -3.104465
# [LightGBM] [Info] Start training from score -3.039083
# [LightGBM] [Info] Start training from score -3.014081
# [LightGBM] [Info] Start training from score -3.118071
# [LightGBM] [Info] Start training from score -3.077797
# [LightGBM] [Info] Start training from score -2.965879
# [LightGBM] [Info] Start training from score -3.064725
# ...

# %%
model_report
# Out:
# {'logicstic_regression': 0.96,
#  'decision_tree': 0.9854545454545455,
#  'random_forest': 0.9890909090909091,
#  'support_vector': 0.9654545454545455,
#  'k_neighbors': 0.9545454545454546,
#  'gaussian_nb': 0.9927272727272727,
#  'gradienct_boosting': 0.9818181818181818,
#  'xgb': 0.9836363636363636,
#  'lgbm': 0.98}

# %%
scores = {'logicstic_regression': 0.96,
 'decision_tree': 0.9854545454545455,
 'random_forest': 0.9890909090909091,
 'support_vector': 0.9654545454545455,
 'k_neighbors': 0.9545454545454546,
 'gaussian_nb': 0.9927272727272727,
 'gradienct_boosting': 0.9818181818181818,
 'xgb': 0.9836363636363636,
 'lgbm': 0.98}

# %%
max_score = 0
best_model = None
models = list(scores.keys())
scores = list(scores.values())
for i in range(len(scores)):
    if max_score < scores[i]:
        max_score = scores[i]
        best_model = models[i]

# %%
max_score
# Out:
# 0.9927272727272727

# %%
best_model
# Out:
# 'gaussian_nb'

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'var_smoothing': [1e-9, 1e-8, 1e-7, 1e-6, 1e-5]
}
gaussian_nb = GaussianNB()
grid_search = GridSearchCV(estimator=gaussian_nb, param_grid=param_grid, cv=5, scoring='accuracy')
grid_search.fit(x_train, y_train)
grid_search.best_params_
# Out:
# {'var_smoothing': 1e-09}

# %%
from scipy.stats import uniform
from sklearn.model_selection import RandomizedSearchCV

# %%
param_dist = {
    'var_smoothing': uniform(1e-9, 1e-5)
}
random_search = RandomizedSearchCV(estimator=gaussian_nb, param_distributions=param_dist, n_iter=10, cv=5, scoring='accuracy', random_state=42)
random_search.fit(x_train, y_train)
random_search.best_params_
# Out:
# {'var_smoothing': 3.746401188473625e-06}

# %%
uniform(1e-9, 1e-5)

# %%
grid_search.best_score_
# Out:
# 0.9939393939393939

# %%
random_search.best_score_
# Out:
# 0.9939393939393939

# %%
grid_gaussian_nb = GaussianNB(var_smoothing=1e-09)

# %%
grid_gaussian_nb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = grid_gaussian_nb.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9927272727272727

# %%
random_gaussian_nb = GaussianNB(var_smoothing=3.746401188473625e-06)
random_gaussian_nb.fit(x_train,y_train)
y_pred = random_gaussian_nb.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9927272727272727
